# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
from astropy import units as u
from astropy import constants as const
from scipy import integrate, optimize

# %%
rc('font', size = 22)

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy import units as u
from astropy import constants as const
from scipy import integrate, optimize

H_o     = 70.0 * (u.km / u.s) / u.Mpc
omega_b = 0.0463
omega_c = 0.233
omega_v = 0.721
omega_r = 1.0E-4
omega_m = omega_c + omega_b
omega   = omega_m + omega_v + omega_r


def H(a):
    _H = H_o * np.sqrt((omega_v + omega_m*a**(-3) + omega_r*a**(-4) -\
                   (omega - 1.0)*a**(-2)))
    return _H.to(u.km/u.s/u.Mpc)
    

def rho_crit(z):
    a = 1.0 / (1.0 + z)
    rho_c = 3.0 * (H(a))**2 / (8.0 * np.pi * const.G)
    rho_c = rho_c.decompose(bases=u.cgs.bases)
    return rho_c.to(u.g/u.cm**(3))

class halo:
    
    def __init__(self, vmax, sigma, f_b, z, T, mu, r_gas = None):
        
        self._vmax      = vmax
        self._sigma     = sigma
        self._f_b       = f_b
        self._z         = z
        self._T         = T
        self._mu        = mu
        self._r_gas     = r_gas

        
        if not hasattr(self._vmax, 'unit'):
            # assume cgs
            self._vmax = self._vmax * u.cm / u.s
            
        if not hasattr(self._T, 'unit'):
            self._T = self._T * u.K
            
     #   if not hasattr(self._r_gas, 'unit') and not self._r_gas == None\
     #       and not 'vir' in self._r_gas and not 'Vir' in self._r_gas:
     #       self._r_gas = self._r_gas * u.cm
        
        self._set_properties()
        
        return
    
    def potential(self, X):
        if hasattr(X,'unit'):
            X = X.decompose(bases=u.cgs.bases)
            if X.unit == u.cm:
                X = X / self.r_s
                X = X.decompose()
            
            X = X.value        
            
        X = np.asarray(X)
        scalar = False
        if X.ndim == 0:
            X = X[None]
            scalar = True
        
        pot = np.zeros(np.size(X)) * (self.vmax.unit)**2
        small_number = 1.0E-16
        pot[X <= small_number] = -75.0 / 32.0 * self.vmax**2 * (np.pi / 2.0)
        x   = X[X > small_number]
        pot[X>small_number] = -75.0 / 32.0 * self.vmax**2 *\
                        ((1.0/x)*(0.5*np.log(1+x**2)+np.log(1+x)-np.arctan(x)) +\
                         np.log(1+x)-0.5*np.log(1+x**2)-np.arctan(x)+np.pi/2.0)
        
        pot = pot.decompose(bases=u.cgs.bases)
        if scalar:
            return np.squeeze(pot)
        else:
            return pot
        
    def mass(self, x):
        if hasattr(x, 'unit'):
            x = x.decompose(bases=u.cgs.bases)
            
            if x.unit == u.cm:
                x = x / self.r_s
                x = x.decompose()
            
            x = x.value
            
        M = 1.5 * self.M_ds * (0.5*np.log(1.0+x**2)+np.log(1.0+x)-np.arctan(x))
        
        return M.decompose(bases=u.cgs.bases)
    
    def gas_density(self, x):
        if hasattr(x, 'unit'):
            x = x.decompose(bases=u.cgs.bases)
            
            if x.unit == u.cm:
                x = x / self.r_s
                x = x.decompose()
                
        return self.rho_s_gas * np.exp(-((self._mu*const.m_p)/(const.k_B*self._T)).decompose() * self.potential(x))
    
    def gas_pressure(self, x):
        if hasattr(x, 'unit'):
            x = x.decompose(bases=u.cgs.bases)
            
            if x.unit == u.cm:
                x = x / self.r_s
                x = x.decompose()
                
        return (self.gas_density(x) / (self._mu * const.m_p) * const.k_B * self._T).decompose(bases=u.cgs.bases)
    
    def _set_properties(self):
        # computes M_vir, R_vir
        def func(x):
            val = self.mass(x) / (4.0 * np.pi * (x*self.r_s)**3 /3.0)
            val = (val.to(u.g/u.cm**3)).value
            
            return (200.0*((rho_crit(self._z)).to(u.g/u.cm**3)).value)\
                   - val
        
        self.R_vir = self.r_s * optimize.brentq(func, 0.01, 100.0)
        self.M_vir = self.mass(self.R_vir / self.r_s)
  

        if not self._r_gas == 'find':
            func  = lambda x : x*x *np.exp(((-self._mu*const.m_p)/(const.k_B*self._T)).decompose()*self.potential(x))

            if self._r_gas == None:
                self._r_gas = self.r_s
            elif 'vir' in [self._r_gas] or 'Vir' in [self._r_gas]:
                self._r_gas = self.R_vir
            else:
                self._r_gas = self._r_gas * self.r_s

            rmax = np.logspace(np.log10((self._r_gas/self.r_s).decompose().value)  - 6,
                                  np.log10((self._r_gas/self.r_s).decompose().value), 20.0)
            denom = 0.0
            for i in np.arange(1, np.size(rmax)):
                denom += integrate.quad(func, rmax[i-1], rmax[i])[0]


            denom = denom * 4.0 * np.pi * self.r_s**3
            self.rho_s_gas = self._f_b * self.M_vir / denom

            self.rho_s_gas = self.rho_s_gas.to(u.g/u.cm**3)
        else:
            a = 1.0 / (1.0 + self._z)
            self.rho_s_gas = omega_m * 1.0 / (a**3) * 3.0 * H_o**2 / (8.0 * np.pi * const.G)
            self.rho_s_gas = self.rho_s_gas.to(u.g / u.cm**3)
            
            func  = lambda x : x*x*\
                                  np.exp(((-self._mu*const.m_p)/(const.k_B*self._T)).decompose()*self.potential(x))
            
            root_func = lambda x : (4.0*np.pi*self.rho_s_gas*integrate.quad(func, 0.0, x)[0]*self.r_s**3 - self.M_gas).decompose(bases=u.cgs.bases).value
            
            
            self._r_gas = optimize.brentq(root_func, 0.0001, 1000.0) * self.r_s
            
            
            
            
    
        return 
                                  
    @property
    def mu(self):
        return self._mu
    @mu.setter
    def mu(self,value):
        self._mu = value
        self._set_properties()
        return
            
                                  
    @property
    def M_gas(self):
        return self.M_vir * self._f_b
    
    @property
    def r_s(self):
        
        r_s = (210.0 * u.pc) * (self.v_s/(1.0E6*u.cm/u.s))**(1.39) *\
                      10.0**(-0.18*self.sigma)
        r_s = r_s.decompose(bases=u.cgs.bases)
        
        return r_s.to(u.cm)
    
    @property
    def v_s(self):
        return self._vmax / 0.8
    
    @property
    def rho_s(self):
        amu = 1.66E-24 * u.g / u.cm**3
        
        rho_s = 5.4 * amu * (self.v_s/(1.0E6*u.cm/u.s))**(-0.78)*\
                     10.0**(0.36*self.sigma)
        rho_s.decompose(bases=u.cgs.bases)
        
        return rho_s.to(u.g / u.cm**3)
    
    @property
    def M_ds(self):
        M_ds = 4.0 * np.pi * self.rho_s * self.r_s**3 / 3.0
        M_ds = M_ds.decompose(bases=u.cgs.bases)
        return M_ds.to(u.g)
    
    @property
    def vmax(self):
        return self._vmax
    
    @vmax.setter
    def vmax(self,value):
        self._vmax = value
        self._set_properties()
        return
    
    @property
    def f_b(self):
        return self._f_b
    
    @f_b.setter
    def f_b(self,value):
        self._f_b = value
        self._set_properties()
        return
    
    @property
    def sigma(self):
        return self._sigma
    
    @sigma.setter
    def sigma(self,value):
        self._sigma = value
        self._set_properites()
        return
    
    def print_properties(self):
        print "r_s   = %.4E pc"%(self.r_s.to(u.pc).value)
        print "v_c   = %.1f km/s"%(self._vmax.to(u.km/u.s).value)
        print "f_b   = %.3f"%(self._f_b)
        print "T     = %.4E K"%(self._T.value)
        print "M_gas = %.4E Msun"%(self.M_gas.to(u.Msun).value)
        print "M_vir = %.4E Msun"%(self.M_vir.to(u.Msun).value)
        print "R_vir = %.4E kpc"%(self.R_vir.to(u.kpc).value)
        rho_s_gas = self.rho_s_gas.to(u.g/u.cm**3)
        n_s_gas   = (rho_s_gas / (self._mu * const.m_p)).decompose(bases=u.cgs.bases)
        print "rho_s_gas = %.2E cgs    n_s_gas = %.2E cgs"%(rho_s_gas.value, n_s_gas.value)
        rho_o_gas = self.gas_density(0.0).to(u.g/u.cm**3)
        n_o_gas   = (rho_o_gas / (self._mu * const.m_p)).decompose(bases=u.cgs.bases)
        print "rho_o_gas = %.2E cgs    n_o_gas =  %.2E cgs"%(rho_o_gas.value, n_o_gas.value)
        
        
    def thermal_gradient(self, x, dx = None):
        if hasattr(x, 'unit'):
            x = x.decompose(bases=u.cgs.bases)
                
            if x.unit == u.cm:
                x = x / self.r_s
                x = x.decompose()
                
        if not dx == None: 
            if hasattr(dx, 'unit'):
                dx = dx.decompose(bases=u.cgs.bases)
              
                if dx.unit == u.cm:
                    dx = dx / self.r_s
                    dx = dx.decompose()
        else:
            dx = 1.0E-3 * x
            
        if np.size(x) > 1:            
            gas_density  = self.gas_density(x[1:])
            gas_pressure = self.gas_pressure(x)
            
            dPdr         = np.diff(gas_pressure) / np.diff(x)
            
        else:
            gas_density  = self.gas_density(x)
            dP           = self.gas_pressure(x+dx) - self.gas_pressure(x) 
            dPdr         = dP / dx
        
        result = dPdr / gas_density / self.r_s
        
        result = result.decompose(bases=u.cgs.bases)
        
        return result
    
    def acceleration(self, x, dx = None):
        if hasattr(x, 'unit'):
            x = x.decompose(bases=u.cgs.bases)
                
            if x.unit == u.cm:
                x = x / self.r_s
                x = x.decompose()
                
        if not dx == None: 
            if hasattr(dx, 'unit'):
                dx = dx.decompose(bases=u.cgs.bases)
                
                if dx.unit == u.cm:
                    dx = dx / self.r_s
                    dx = dx.decompose()
        else:
            dx = 1.0E-3 * x
            
        if np.size(x) > 1:
            dPhidr = np.diff( self.potential(x)) / np.diff(x)
            
        else:
            dPhidr = (self.potential(x+dx) - self.potential(x)) / dx
        
        dPhidr = dPhidr / self.r_s
        dPhidr = dPhidr.decompose(bases=u.cgs.bases)
        
        return dPhidr

# %%
rscale = 0.5

ldict = {0.0001 : r'1.0$\times$10$^{-4}$', 0.00025: r'2.5$\times$10$^{-4}$',
         0.0005 : r'5.0$\times$10$^{-4}$', 0.00075: r'7.5$\times$10$^{-4}$',
         0.001  : r'1.0$\times$10$^{-3}$', 0.005  : r'5.0$\times$10$^{-3}$',
         0.0075 : r'7.5$\times$10$^{-3}$', 0.010: r'0.01', 0.015: r'0.015'}
show_HSE = True

# %%
ldict[0.001]
# Out:
# '1.0$\\times$10$^{-3}$'

# %%
i = 0

ncrit = rho_crit(0.0) / (1.66E-24 * u.g)

fig, ax = plt.subplots(1,3)

ax1 = ax[0]
ax2 = ax[1]
ax3 = ax[2]

ax1.set_title('HI and HeI Shielding - z = 0.0')

metallicities = [0.0001, 0.00025, 0.0005, 0.00075, 0.001, 0.005, 0.0075, 0.010, 0.015]
ls            = ['-','--','-.',':']
for z in metallicities:
    try:

        data = np.genfromtxt('./Gyr/lowres/uvb_eq_Z=%.5f_z=0.0.txt'%(z),names=True)
    
    
        ax1.plot(data['n'],data['T'], lw=3, color ='black', ls =ls[i],
                 label=ldict[z])
    except:
        print "did not load", z
    i = i + 1
    
    if i == len(ls):
        i = 0
ax2.set_title('HI Shielding ONLY - z = 0.0')
i = 0        

metallicities = [0.0001, 0.00025, 0.0005, 0.00075, 0.001, 0.005,0.0075, 0.010, 0.015]
ls            = ['-','--','-.',':']
for z in metallicities:
    try:
        data = np.genfromtxt('./Gyr/lowres/no_He_shielding/uvb_eq_Z=%.5f_z=0.0.txt'%(z),names=True)
    
    
        ax2.plot(data['n'],data['T'], lw=3, color ='black', ls =ls[i],
                 label=ldict[z])
    except:
        print "data file not loaded", z
    i = i + 1
    
    if i == len(ls):
        i = 0

i = 0        

ax3.set_title('No Shielding - z = 0.0')        

metallicities = [0.0001, 0.00025, 0.0005, 0.00075, 0.001, 0.005,0.0075, 0.010, 0.015]
ls            = ['-','--','-.',':']
for z in metallicities:
    try:
        data = np.genfromtxt('./Gyr/lowres/no_shielding/uvb_eq_Z=%.5f_z=0.0.txt'%(z),names=True)
    
    
        ax3.plot(data['n'],data['T'], lw=3, color ='black', ls =ls[i],
                 label=ldict[z])
    except:
        print "data file not loaded", z
    i = i + 1
    
    if i == len(ls):
        i = 0        

ax3.legend(loc='best', ncol = 2)

for a in [ax1,ax2,ax3]:
    a.loglog()
    a.set_xlabel('Number Density')
    a.set_ylabel('Temperature (K)')
    a.set_ylim(1.0, 1.0E5)


fig.set_size_inches(30,10)
plt.tight_layout()
j = 0

if show_HSE:
    for v in [10.0, 20.0, 50.0, 100.0]:

        Tvals = np.logspace(0.0, 5.0, 20.0)
        nvals = np.zeros(np.size(Tvals))
        i = 0
        for t in Tvals:
            h   = halo(vmax = v*u.km/u.s, sigma = 0.0, f_b = 0.01, z = 0.0, T = t, mu = 1.1, r_gas = 2.0)
            n_o = h.gas_density(rscale) / (h.mu * const.m_p)
            n_o = n_o.to('cm**(-3)')

            nvals[i] = n_o.value
            i = i + 1

        for a in [ax1,ax2,ax3]:
            a.plot(nvals, Tvals, lw = 3, color = 'blue', ls = ls[j])

        j = j + 1

        if j == len(ls):
            j = 0
            
        print h._r_gas.to(u.pc), h.rho_s_gas.to(u.g/u.cm**3), h.M_gas.to(u.Msun)
        
    fig.savefig('temperature_density_%.2f.png'%(rscale))
else:
    fig.savefig('temperature_density.png')
# Out:
# /home/emerick/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:129: RuntimeWarning: overflow encountered in exp
# /home/emerick/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:104: RuntimeWarning: overflow encountered in exp
# 572.735639202 pc 5.16449136449e-26 g / cm3 892130.250764 solMass
# 1501.01800753 pc 8.45141410347e-27 g / cm3 8669472.26121 solMass
# 5364.41680696 pc 6.75023223202e-31 g / cm3 173434950.512 solMass
# 14058.9927988 pc 5.82161970016e-46 g / cm3 1657574438.66 solMass

# %%
i = 0

fig, ax = plt.subplots(1,3)

ax1 = ax[0]
ax2 = ax[1]
ax3 = ax[2]

metallicities = [0.0001, 0.00025, 0.0005, 0.00075, 0.001, 0.005, 0.0075, 0.010, 0.015]
ls            = ['-','--','-.',':']
for z in metallicities:
    try:
        data = np.genfromtxt('./Gyr/lowres/uvb_eq_Z=%.5f_z=0.0.txt'%(z),names=True)
    
    
        ax1.plot(data['P'],data['T'], lw=3, color ='black', ls =ls[i],
            label=ldict[z])
    except:
        print 'did not load', z
   
    i = i + 1
    
    if i == len(ls):
        i = 0

i = 0        
metallicities = [0.0001, 0.00025, 0.0005, 0.00075, 0.001, 0.005, 0.0075, 0.010, 0.015]
ls            = ['-','--','-.',':']
for z in metallicities:
    try:
        data = np.genfromtxt('./Gyr/lowres/no_He_shielding/uvb_eq_Z=%.5f_z=0.0.txt'%(z),names=True)
    
    
        ax2.plot(data['P'],data['T'], lw=3, color ='black', ls =ls[i],
                 label=ldict[z])
    except:
        print "file not loaded", z
        
    i = i + 1
    
    if i == len(ls):
        i = 0

i = 0        
metallicities = [0.0001, 0.00025, 0.0005, 0.00075, 0.001, 0.005, 0.0075, 0.010, 0.015]
ls            = ['-','--','-.',':']
for z in metallicities:
    try:
        data = np.genfromtxt('./Gyr/lowres/no_shielding/uvb_eq_Z=%.5f_z=0.0.txt'%(z),names=True)
    
    
        ax3.plot(data['P'],data['T'], lw=3, color ='black', ls =ls[i],
                 label=ldict[z])
    except:
        print "file not loaded", z
        
    i = i + 1
    
    if i == len(ls):
        i = 0        
        
ax3.legend(loc='best', ncol=2)        
for a in [ax1,ax2,ax3]:
    a.loglog()
    a.set_xlabel('Pressure (cgs)')
    a.set_ylabel('Temperature (K)')
    a.set_ylim(1.0, 1.0E5)
    a.set_xlim(1.0E-15, 1.0E-7)
ax1.set_title('HI and HeI Shielding - z = 0.0')
ax2.set_title('HI Shielding ONLY - z = 0.0')
ax3.set_title('No Shielding - z = 0.0')

fig.set_size_inches(30,10)
plt.tight_layout()

j = 0
if show_HSE:
    for v in [10.0, 15.0, 20.0, 25.0, 50.0, 100.0]:

        Tvals = np.logspace(0.0, 5.0, 20.0)
        Pvals = np.zeros(np.size(Tvals))
        i = 0
        for t in Tvals:
            h   = halo(vmax = v*u.km/u.s, sigma = 0.0, f_b = 0.1, z = 0.0, T = t, mu = 1.1, r_gas = 1.0)
            P_o = h.gas_pressure(rscale) 

            Pvals[i] = P_o.value
            i = i + 1

        for a in [ax1,ax2,ax3]:
            a.plot(Pvals, Tvals, lw = 3, color = 'blue', ls = ls[j])

        j = j + 1

        if j == len(ls):
            j = 0       


    fig.savefig('temperature_pressure_%.2f.png'%(rscale))
else:
    fig.savefig('temperature_pressure.png')
# Out:
# /home/emerick/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:129: RuntimeWarning: overflow encountered in exp
# /home/emerick/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:104: RuntimeWarning: overflow encountered in exp

# %% [markdown]
# #### i = 0
#
# metallicities = [0.0001, 0.00025, .0005, 0.00075]
# ls            = ['-','--','-.',':']
# for z in metallicities:
#     data = np.genfromtxt('uvb_eq_Z=%.5f_z=1.0.txt'%(z),names=True)
#
#
#     plt.plot(data['n'],data['T'], lw=3, color ='black', ls =ls[i],
#              label="Z=%.4f"%(z))
#     i = i + 1
#
#     if i == len(ls):
#         i = 0
#
# plt.loglog()
# plt.legend(loc='best')
# plt.xlabel('Number Density')
# plt.ylabel('Temperature (K)')

# %%
i = 0

ncrit = ((rho_crit(0.0) / (1.66E-24 * u.g)).decompose(bases=u.cgs.bases)).value

fig, ax = plt.subplots(1,3)

ax1 = ax[0]
ax2 = ax[1]
ax3 = ax[2]

ax1.set_title('HI and HeI Shielding - z = 0.0')

metallicities = [0.0001, 0.00025, 0.0005, 0.00075, 0.001, 0.005, 0.0075, 0.010, 0.015]
ls            = ['-','--','-.',':']
for z in metallicities:
    try:

        data = np.genfromtxt('./Gyr/lowres/uvb_eq_Z=%.5f_z=0.0.txt'%(z),names=True)
    
    
        ax1.plot(data['n']/ncrit,data['T'], lw=3, color ='black', ls =ls[i],
                 label=ldict[z])
    except:
        print "did not load", z
    i = i + 1
    
    if i == len(ls):
        i = 0
ax2.set_title('HI Shielding ONLY - z = 0.0')
i = 0        

metallicities = [0.0001, 0.00025, 0.0005, 0.00075, 0.001, 0.005,0.0075, 0.010, 0.015]
ls            = ['-','--','-.',':']
for z in metallicities:
    try:
        data = np.genfromtxt('./Gyr/lowres/no_He_shielding/uvb_eq_Z=%.5f_z=0.0.txt'%(z),names=True)
    
    
        ax2.plot(data['n']/ncrit,data['T'], lw=3, color ='black', ls =ls[i],
                 label=ldict[z])
    except:
        print "data file not loaded", z
    i = i + 1
    
    if i == len(ls):
        i = 0

i = 0        

ax3.set_title('No Shielding - z = 0.0')        

metallicities = [0.0001, 0.00025, 0.0005, 0.00075, 0.001, 0.005,0.0075, 0.010, 0.015]
ls            = ['-','--','-.',':']
for z in metallicities:
    try:
        data = np.genfromtxt('./Gyr/lowres/no_shielding/uvb_eq_Z=%.5f_z=0.0.txt'%(z),names=True)
    
    
        ax3.plot(data['n']/ncrit,data['T'], lw=3, color ='black', ls =ls[i],
                 label=ldict[z])
    except:
        print "data file not loaded", z
    i = i + 1
    
    if i == len(ls):
        i = 0        

ax3.legend(loc='best', ncol = 2)

for a in [ax1,ax2,ax3]:
    a.loglog()
    a.set_xlabel('Number Density')
    a.set_ylabel('Temperature (K)')
    a.set_ylim(1.0, 1.0E5)


fig.set_size_inches(30,10)
plt.tight_layout()
if show_HSE:
    j = 0
    for v in [10.0, 20.0, 50.0, 100.0]:

        Tvals = np.logspace(0.0, 5.0, 20.0)
        nvals = np.zeros(np.size(Tvals))
        i = 0
        for t in Tvals:
            h   = halo(vmax = v*u.km/u.s, sigma = 0.0, f_b = 0.1, z = 0.0, T = t, mu = 1.1)
            n_o = h.gas_density(rscale) / (h.mu * const.m_p)
            n_o = n_o.to('cm**(-3)')

            nvals[i] = n_o.value
            i = i + 1

        for a in [ax1,ax2,ax3]:
            a.plot(nvals/ncrit, Tvals, lw = 3, color = 'blue', ls = ls[j])

        j = j + 1

        if j == len(ls):
            j = 0        
    fig.savefig('temperature_density_ncrit_%.2f.png'%(rscale))
else:
    fig.savefig('temperature_density_ncrit.png')

# %%
i = 0

fig, ax = plt.subplots(1,3)

ax1 = ax[0]
ax2 = ax[1]
ax3 = ax[2]

metallicities = [0.0001, 0.00025, 0.0005, 0.00075, 0.001, 0.005, 0.0075, 0.010, 0.015]
ls            = ['-','--','-.',':']
for z in metallicities:
    try:
        data = np.genfromtxt('./Gyr/lowres/uvb_eq_Z=%.5f_z=0.0.txt'%(z),names=True)
    
    
        ax1.plot(data['n'],data['P'], lw=3, color ='black', ls =ls[i],
            label=ldict[z])
    except:
        print 'did not load', z
   
    i = i + 1
    
    if i == len(ls):
        i = 0

i = 0        
metallicities = [0.0001, 0.00025, 0.0005, 0.00075, 0.001, 0.005, 0.0075, 0.010, 0.015]
ls            = ['-','--','-.',':']
for z in metallicities:
    try:
        data = np.genfromtxt('./Gyr/lowres/no_He_shielding/uvb_eq_Z=%.5f_z=0.0.txt'%(z),names=True)
    
    
        ax2.plot(data['n'],data['P'], lw=3, color ='black', ls =ls[i],
                 label=ldict[z])
    except:
        print "file not loaded", z
        
    i = i + 1
    
    if i == len(ls):
        i = 0

i = 0        
metallicities = [0.0001, 0.00025, 0.0005, 0.00075, 0.001, 0.005, 0.0075, 0.010, 0.015]
ls            = ['-','--','-.',':']
for z in metallicities:
    try:
        data = np.genfromtxt('./Gyr/lowres/no_shielding/uvb_eq_Z=%.5f_z=0.0.txt'%(z),names=True)
    
    
        ax3.plot(data['n'],data['P'], lw=3, color ='black', ls =ls[i],
                 label=ldict[z])
    except:
        print "file not loaded", z
        
    i = i + 1
    
    if i == len(ls):
        i = 0        
        
ax3.legend(loc='best', ncol=2)        
for a in [ax1,ax2,ax3]:
    a.loglog()
    a.set_ylabel('Pressure (cgs)')
    a.set_xlabel('Number Density (cgs)')
    a.set_ylim(1.0E-15, 1.0E-7)
    a.set_xlim(1.0E-4, 1.0E3)
ax1.set_title('HI and HeI Shielding - z = 0.0')
ax2.set_title('HI Shielding ONLY - z = 0.0')
ax3.set_title('No Shielding - z = 0.0')

fig.set_size_inches(30,10)
plt.tight_layout()

j = 0
if False:
    for v in [10.0, 15.0, 20.0, 25.0, 50.0, 100.0]:

        Tvals = np.logspace(0.0, 5.0, 20.0)
        Pvals = np.zeros(np.size(Tvals))
        i = 0
        for t in Tvals:
            h   = halo(vmax = v*u.km/u.s, sigma = 0.0, f_b = 0.1, z = 0.0, T = t, mu = 1.1, r_gas = 1.0)
            P_o = h.gas_pressure(rscale) 

            Pvals[i] = P_o.value
            i = i + 1

        for a in [ax1,ax2,ax3]:
            a.plot(Pvals, Tvals, lw = 3, color = 'blue', ls = ls[j])

        j = j + 1

        if j == len(ls):
            j = 0       


    fig.savefig('temperature_pressure_%.2f.png'%(rscale))
else:

    fig.savefig('pressure_density.png')

# %%
fig, axes = plt.subplots(1,2)
i = 0
vcirc = np.linspace(1.0, 100.0, 25)
Nvals = np.zeros(np.size(vcirc))

ax1 = axes[0]
ax2 = axes[1]

j = 1
for T in [5.0E3, 1.0E4]:
    i = 0
    for v in vcirc:

        h   = halo(vmax = v*u.km/u.s, sigma = 0.0, f_b = 0.01, z = 0.0, T = T, mu = 1.1, r_gas = 'vir')
        n_o = h.gas_density(rscale) / (h.mu * const.m_p)

        func = lambda x : h.gas_density(x).value

        N    = h.r_s * (integrate.quad(func, 0.0, (h.R_vir/h.r_s).decompose().value)[0])*u.g*u.cm**(-3) / (h.mu * const.m_p)
        Nvals[i] = N.to(u.cm**(-2)).value * 2.0 * 0.72
        i  = i + 1

    ax1.plot(vcirc, Nvals , lw = 3, color = 'black', ls = ls[j], label = r'T$_{\rm 4, iso}$ = %.2f'%(T / 1.0E4))
    ax2.plot(vcirc, Nvals * 2.82E-18, lw = 3, color = 'black', ls = ls[j])
    j = j - 1

for ax in axes:
    ax.set_xlabel('Velocity (km/s)')
    ax.semilogy()
    ax.minorticks_on()
plt.minorticks_on()
ax2.set_ylabel('Optical Depth')
ax1.set_ylabel('Column Density (cm)')
ax1.legend(loc='best')
fig.set_size_inches(16,8)
plt.tight_layout()
fig.savefig('column_density.png')
# Out:
# /home/emerick/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:129: RuntimeWarning: overflow encountered in exp
# /home/emerick/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:104: RuntimeWarning: overflow encountered in exp
